# %%
import pandas as pd
import ffn
import datetime
import seaborn as sns

table = pd.read_html('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]

# %%
stockdata = df['Symbol'].to_list()
print(stockdata)

# %%
prices = ffn.get('AAPL', start='2021-01-01')
print(prices)
# Out:
#                   aapl
# Date
# 2020-12-31  131.333557
# 2021-01-04  128.087082
# 2021-01-05  129.670700
# 2021-01-06  125.305801
# 2021-01-07  129.581650
# ...                ...
# 2022-09-13  153.839996
# 2022-09-14  155.309998
# 2022-09-15  152.369995
# 2022-09-16  150.699997
# 2022-09-19  154.479996
#
# [432 rows x 1 columns]

# %%
stock = ffn.get("SPY:Open,SPY:High,SPY:Low,SPY:Close,SPY", start='2022-09-10',)
print(stock.dtypes)
print(stock)

# %%
FAANG = "META,AMZN,NFLX,GOOGL,AAPL"

# %%
stock = ffn.get(FAANG, start='2020-09-10',)

# %%
print(stock.isnull().sum().sum())
# Out:
# 0

# %%
# %matplotlib inline

stock.plot_corr_heatmap()
# Out:
# <module 'matplotlib.pyplot' from '/Users/henrytsui/miniforge3/envs/IDS/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
print(stock.rebase())
stock_blur = stock.rolling(15).mean()
stock_blur.dropna(inplace=True)
ax = stock_blur.rebase().plot(figsize=(12,5))
# Out:
#                   meta        amzn        nflx       googl        aapl
# Date
# 2020-09-09  100.000000  100.000000  100.000000  100.000000  100.000000
# 2020-09-10   97.943152   97.139455   96.097485   98.631095   96.735425
# 2020-09-11   97.402449   95.337779   96.369379   97.966041   95.465394
# 2020-09-14   97.234397   94.932404   95.215819   97.518138   98.329355
# 2020-09-15   99.525067   96.558786   99.160317   99.217302   98.482778
# ...                ...         ...         ...         ...         ...
# 2022-09-14   55.337571   78.657292   44.806972  135.726421  133.979546
# 2022-09-15   54.636125   77.268320   47.058119  133.024824  131.443327
# 2022-09-16   53.445124   75.585648   48.007758  132.882633  130.002689
# 2022-09-19   54.077160   76.277076   48.707492  133.231640  133.263538
# 2022-09-20   53.372057   74.765729   48.551551  130.736858  135.351171
#
# [512 rows x 5 columns]

# %%
# ax = stock.rebase().plot(figsize=(12,5))
ax = stock_blur.rebase().plot(figsize=(12,5))

# %%
plt.plot([2, 2],)
plt.show()
# Out:
# /var/folders/g5/4576b0tj6k3g5p1pxwxvnjq80000gn/T/ipykernel_11810/1770054203.py:2: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
full_stock_data.to_csv('src/stock_data/stock.csv', sep='\t')

# %%
print(full_stock_data.index[-1])
# Out:
# 2022-09-19 00:00:00

# %%
type(full_stock_data.index[-1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
a = datetime.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
c = datetime.datetime(2022,9, 21)
d = full_stock_data.index[-1]
print(a, c, d)
# Out:
# 2022-09-21 00:00:00 2022-09-21 00:00:00 2022-09-19 00:00:00

# %%
print(c == a)
if( a > d): print("ADF")
else : print("ASDF")
# Out:
# True
# ASDF

# %%
begin = datetime.date.today()
begin = datetime.datetime(2022,9, 21)
enday = full_stock_data.index[-1]

if enday == begin:
    print("ASDF")
else :
    print("ADFS")
print(begin, enday)
# Out:
# ASDF
# 2022-09-19 00:00:00 2022-09-19 00:00:00

# %%
pd.to_datetime(df['mydates']).apply(lambda x: x.date())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 print(full_stock_data.dt.date)
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/pandas/core/generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dt'

# %%
print(type(enday), type(begin))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'datetime.date'>

# %%
print(enday[:-1])
full_stock_data.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 print(enday[:-1])
#
# TypeError: 'Timestamp' object is not subscriptable
