# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import ffn
# %matplotlib inline

# %%
def slide_windows(stock):
    return stock.rolling(10).mean(std = 5)

# %%
prices = pd.read_csv("../data/stock.csv", index_col=0)
slide_windows(prices).iloc[-400:, :].rebase().plot()
# Out:
# /var/folders/g5/4576b0tj6k3g5p1pxwxvnjq80000gn/T/ipykernel_42324/2670613199.py:2: FutureWarning: Passing additional kwargs to Rolling.mean has no impact on the result and is deprecated. This will raise a TypeError in a future version of pandas.
#   return stock.rolling(10).mean(std = 5)
# <AxesSubplot: xlabel='Date'>

# %%
slide_windows(prices).iloc[-60:].to_drawdown_series().plot()
# Out:
# /var/folders/g5/4576b0tj6k3g5p1pxwxvnjq80000gn/T/ipykernel_42324/2670613199.py:2: FutureWarning: Passing additional kwargs to Rolling.mean has no impact on the result and is deprecated. This will raise a TypeError in a future version of pandas.
#   return stock.rolling(10).mean(std = 5)
# <AxesSubplot: xlabel='Date'>

# %%
stats = prices.calc_stats()
stats.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 stats = prices.calc_stats()
#       2 stats.display()
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:1228, in calc_stats(prices)
#    1226     return PerformanceStats(prices)
#    1227 elif isinstance(prices, pd.DataFrame):
# -> 1228     return GroupStats(*[prices[x] for x in prices.columns])
#    1229 else:
#    1230     raise NotImplementedError("Unsupported type")
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:837, in GroupStats.__init__(self, *prices)
#     835 self._end = self._prices.index[-1]
#     836 # calculate stats for entire series
# --> 837 self._update(self._prices)
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:847, in GroupStats._update(self, data)
#     846 def _update(self, data):
# --> 847     self._calculate(data)
#     848     self._update_stats()
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:854, in GroupStats._calculate(self, data)
#     852 for c in data.columns:
#     853     prc = data[c]
# --> 854     self[c] = PerformanceStats(prc)
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:72, in PerformanceStats.__init__(self, prices, rf)
#      68 self._end = self.prices.index[-1]
#      70 self.rf = rf
# ---> 72 self._update(self.prices)
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:91, in PerformanceStats._update(self, obj)
#      89 def _update(self, obj):
#      90     # calc
# ---> 91     self._calculate(obj)
#      93     # update derived structure
#      94     # return table as dataframe for easier manipulation
#      95     self.return_table = pd.DataFrame(self.return_table).T
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/ffn/core.py:193, in PerformanceStats._calculate(self, obj)
#     190 self.end = obj.index[-1]
#     192 # save daily prices for future use
# --> 193 self.daily_prices = obj.resample("D").last()
#     194 # resample('D') imputes na values for any day that didn't have a price
#     195 #  .dropna() removes the na values but also implies that the original
#     196 #  price series didn't have any na values
#     197 #  if months or years are missing then we will need .dropna() too
#     198 self.daily_prices = self.daily_prices.dropna()
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/pandas/core/series.py:5875, in Series.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    5858 @doc(NDFrame.resample, **_shared_doc_kwargs)  # type: ignore[has-type]
#    5859 def resample(
#    5860     self,
#    (...)
#    5873     group_keys: bool | lib.NoDefault = no_default,
#    5874 ) -> Resampler:
# -> 5875     return super().resample(
#    5876         rule=rule,
#    5877         axis=axis,
#    5878         closed=closed,
#    5879         label=label,
#    5880         convention=convention,
#    5881         kind=kind,
#    5882         loffset=loffset,
#    5883         base=base,
#    5884         on=on,
#    5885         level=level,
#    5886         origin=origin,
#    5887         offset=offset,
#    5888         group_keys=group_keys,
#    5889     )
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/pandas/core/generic.py:8863, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8860 from pandas.core.resample import get_resampler
#    8862 axis = self._get_axis_number(axis)
# -> 8863 return get_resampler(
#    8864     self,
#    8865     freq=rule,
#    8866     label=label,
#    8867     closed=closed,
#    8868     axis=axis,
#    8869     kind=kind,
#    8870     loffset=loffset,
#    8871     convention=convention,
#    8872     base=base,
#    8873     key=on,
#    8874     level=level,
#    8875     origin=origin,
#    8876     offset=offset,
#    8877     group_keys=group_keys,
#    8878 )
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/pandas/core/resample.py:1518, in get_resampler(obj, kind, **kwds)
#    1514 """
#    1515 Create a TimeGrouper and return our resampler.
#    1516 """
#    1517 tg = TimeGrouper(**kwds)
# -> 1518 return tg._get_resampler(obj, kind=kind)
#
# File ~/miniforge3/envs/IDS/lib/python3.8/site-packages/pandas/core/resample.py:1699, in TimeGrouper._get_resampler(self, obj, kind)
#    1694 elif isinstance(ax, TimedeltaIndex):
#    1695     return TimedeltaIndexResampler(
#    1696         obj, groupby=self, axis=self.axis, group_keys=self.group_keys
#    1697     )
# -> 1699 raise TypeError(
#    1700     "Only valid with DatetimeIndex, "
#    1701     "TimedeltaIndex or PeriodIndex, "
#    1702     f"but got an instance of '{type(ax).__name__}'"
#    1703 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
