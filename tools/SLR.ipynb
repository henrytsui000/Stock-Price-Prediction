# %%
import sklearn
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(1)
print(x)
y = 3 * x - 5 + rng.randn(1)
plt.scatter(x, y)
# Out:
# [4.17022005]
