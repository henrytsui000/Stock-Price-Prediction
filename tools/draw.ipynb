# %%
import ffn
import pandas as pd
# %matplotlib inline

# %%
prices = ffn.get("META, AMZN, AAPL, NFLX, GOOG")
# Out:
#                   meta       amzn       aapl        nflx       goog
# Date
# 2017-09-25  162.869995  46.989498  35.720448  178.550003  46.048500
# 2017-09-26  164.210007  46.930000  36.334969  179.380005  46.243000
# 2017-09-27  167.679993  47.543499  36.593590  181.970001  47.224499
# 2017-09-28  168.729996  47.820000  36.368187  180.699997  47.474998
# 2017-09-29  170.869995  48.067501  36.567490  181.350006  47.955502

# %%
prices.rolling(10).mean(std = 5).iloc[-60:, :].rebase().plot()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27800\2984142291.py:1: FutureWarning: Passing additional kwargs to Rolling.mean has no impact on the result and is deprecated. This will raise a TypeError in a future version of pandas.
#   prices.rolling(10).mean(std = 5).iloc[-60:, :].rebase().plot()
# <AxesSubplot: xlabel='Date'>
